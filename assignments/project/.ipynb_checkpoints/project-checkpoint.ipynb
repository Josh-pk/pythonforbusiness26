# %% [markdown]
# # Statement of AI use
# AI was used to either fix or improve codes.

# %% [markdown]
# # Introduction
# # Steam Games Analytics
# ## Project Goal
# The goal of this project is to analyse Steam video game data to better understand trends in pricing, popularity, reviews, and game releases
#
# The project investigates questions such as:
# - What price range are most common in Steam games?
# - Does higher game price correlate with better review scores?
# - How have game releases changed over time?
# - Which genre are most common?
#
# ## How to run this notebook
# 1. Install required libraries
#    - pandas
#    - matplotlib
#    - seaborn
#    - requests
#    - python-dotenv
#    - kagglehub
#
# 2. Download Steam game dataset from:
# https://www.kaggle.com/datasets/fronkongames/steam-games-dataset
#
# 3. Place the dataset CSV file in the same folder as this noteook
#
# 4. Run all notebook cells from top to bottom
#
# ## Files produced:
# - exports/raw_steam_data.csv
# - exports/cleaned_steam_data.csv
# - exports/summary_statistics.csv

# %% [markdown]
# # Import libraries and Load dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import numpy as np
import os
import kagglehub

from IPython.display import display

# Download dataset
path = kagglehub.dataset_download("fronkongames/steam-games-dataset")

df = pd.read_csv(f"{path}/games.csv")

display(df.head())
display(df.shape)

print(os.listdir(path))
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# ...

# %% [markdown]
# #

# %%
os.makedirs("exports", exist_ok=True)
df.to_csv("exports/raw_steam_data.csv", index=False)
print("Raw data has been exported.")
# Out:
# Raw data has been exported.

# %% [markdown]
# # Data cleaning and Transformation

# %%
# Remove duplicates
df = df.drop_duplicates()

# Handle missing values
df = df.dropna(subset=["Price", "Metacritic score"])

# Clean column names
df.columns = df.columns.str.strip()

# Parse dates
df["release_date"] = pd.to_datetime(
    df["Release date"],
    format="%b %d, %Y",
    errors="coerce"
)

# Year extraction
df["release_year"] = df["release_date"].dt.year

# Numeric safety
df["Positive"] = pd.to_numeric(df["Positive"], errors="coerce")
df["Negative"] = pd.to_numeric(df["Negative"], errors="coerce")

df["total_reviews"] = df["Positive"].fillna(0) + df["Negative"].fillna(0)

display(df.head())
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# ...

# %% [markdown]
# # Summary Statistics

# %%
summary_stats = df[[
    "Price",
    "Metacritic score",
    "Positive",
    "Negative",
    "total_reviews"
]].describe()

display(summary_stats)
# Out:
#                Price  Metacritic score      Positive      Negative  \
# count  122604.000000     122604.000000  1.226040e+05  1.226040e+05
# mean       18.354711          2.565088  1.045046e+03  1.692071e+02
# std        28.859460         13.660935  2.809253e+04  5.374798e+03
# min         0.000000          0.000000  0.000000e+00  0.000000e+00
# 25%         0.000000          0.000000  0.000000e+00  0.000000e+00
# 50%         0.000000          0.000000  5.000000e+00  1.000000e+00
# 75%        40.000000          0.000000  3.700000e+01  1.000000e+01
# max       100.000000         97.000000  7.642084e+06  1.173003e+06
#
#        total_reviews
# count   1.226040e+05
# mean    1.214253e+03
# std     3.263772e+04
# min     0.000000e+00
# 25%     0.000000e+00
# 50%     7.000000e+00
# 75%     4.900000e+01
# max     8.815087e+06

# %% [markdown]
# # Visualisation 1 - Price distribution

# %%
plt.figure(figsize=(10,5))

sns.histplot(df["Price"], bins=50)

plt.title("Distributions of Steam Games Prices")
plt.xlabel("Price (USD)")
plt.ylabel("Number of Games")

plt.show()

# %% [markdown]
# # Visualisation 2 - Price vs Metacritic Score

# %%
plt.figure(figsize=(10,5))

sns.scatterplot(
    data=df,
    x="Price",
    y="Metacritic score",
    alpha=0.5
)

plt.title("Game Price vs Metacritic Score")
plt.xlabel("Price")
plt.ylabel("Metacritic Score")

plt.show()

# %% [markdown]
# # Visualisation 3 - Game Releases Over Time

# %%
plt.figure(figsize=(12,5))

sns.histplot(df["Name"].dropna(), bins=30)

plt.title("Number of Steam Games Released Over Time")
plt.xlabel("Release Year")
plt.ylabel("Number of Games")

plt.show()

# %% [markdown]
# # Correlation Analysis

# %%
correlation = df[[
    "Price",
    "Metacritic score",
    "Positive",
    "Negative",
    "total_reviews"
]].corr()

display(correlation)
# Out:
#                      Price  Metacritic score  Positive  Negative  \
# Price             1.000000          0.201785  0.027593  0.016685
# Metacritic score  0.201785          1.000000  0.108569  0.068667
# Positive          0.027593          0.108569  1.000000  0.818396
# Negative          0.016685          0.068667  0.818396  1.000000
# total_reviews     0.026498          0.104757  0.995512  0.869105
#
#                   total_reviews
# Price                  0.026498
# Metacritic score       0.104757
# Positive               0.995512
# Negative               0.869105
# total_reviews          1.000000

# %%
# Heatmap
plt.figure(figsize=(8,6))

sns.heatmap(correlation, annot=True, cmap="coolwarm")

plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# # Export Cleaned Data & Results

# %%
df.to_csv("exports/cleaned_steam_data.csv", index=False)

summary_stats.to_csv("exports/summary_statistics.csv")

print("Cleaned data and results exported")
# Out:
# Cleaned data and results exported

# %% [markdown]
# # Conclusion
# This project analyzed Steam video game data to explore pricing, popularity, and review trends.
#
# Key findings:
# - Most Steam games are low-priced or free-to-play.
# - Higher prices do not necessarily correspond to higher Metacritic scores.
# - The number of games released on Steam has increased significantly over time.
# - Review counts show stronger relationships with popularity than price alone.
#
# The analysis demonstrates how data science techniques such as cleaning, visualization, statistical analysis, and API integration can be used to better understand trends in the gaming industry.
